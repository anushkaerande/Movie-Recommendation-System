# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

#cimporting csv file and extracting particular columns
df = pd.read_csv("movies.csv")
features = ['keywords','cast','genres','director']

#combining features function
def combine_features(row):
    return row['keywords']+" "+row['cast']+" "+row['genres']+" "+row['director']

for feature in features:
    df[feature] = df[feature].fillna('') #filling all NaNs with blank string

df["combined_features"] = df.apply(combine_features,axis=1)
df.iloc[0].combined_features

cv = CountVectorizer() #creating new CountVectorizer() object
count_matrix = cv.fit_transform(df["combined_features"]) #feeding combined strings(movie contents) to CountVectorizer() object
cosine_sim = cosine_similarity(count_matrix)

def get_title_from_index(index):
    return df[df.index == index]["title"].values[0]
def get_index_from_title(title):
    return df[df.title == title]["index"].values[0]

movie_user_likes = input("Ënter movie")
movie_index = get_index_from_title(movie_user_likes)
similar_movies = list(enumerate(cosine_sim[movie_index]))     
sorted_similar_movies = sorted(similar_movies,key=lambda x:x[1],reverse=True)[1:]
i=0

print("Top 10 similar movies to "+movie_user_likes+ " are:\n")
for element in sorted_similar_movies:
    print(get_title_from_index(element[0]))
    i=i+1
    if i>10:
        break   


# In[66]:


from tkinter import *
import tkinter as tk
from PIL import Image,ImageTk

root=tk.Tk()
root.geometry("600x400")
root.title("Recommendations")
root.configure(background="black")


canvas1 = tk.Canvas(root, width = 400, height = 400,bg='red')
canvas1.pack()
canvas1.place(x=100,y=50)
entry1 = tk.Entry (root)
canvas1.create_window(200, 80, window=entry1)
label1 = tk.Label(root, text="Enter your favourite movie here ;)",font=("Arial Italic",14),bg='red4',fg='white')
canvas1.create_window(200, 50, window=label1)
label2 = tk.Label(root, text="You would like to watch :",font=("Arial Italic",10),bg='red4',fg='white')
canvas1.create_window(200, 120, window=label2)
#L1=tk.Label(root,text="Enter your favourite movie here",font=("Arial Italic",14),bg='red',fg='white')
#L1.pack()
#E1 = Entry(root, bd =2)
#E1.pack(side = TOP)

root.mainloop()


# In[1]:


import os
from tkinter import *
import tkinter as tk
from PIL import Image,ImageTk

root=tk.Tk()
def movie():
    os.system('python Movierecommendation.ipynb')
    

root.geometry("600x400")
root.title("Movie Recommendation System")
root.configure(background="black")
   
image1 = Image.open(r"MOVIES (2).jpg")
resize_image = image1.resize((100,100))
test = ImageTk.PhotoImage(image1,resize_image)
label1 = tk.Label(image=test)
label1.image = test
label1.pack(fill='both',expand=1)
button = Button(label1 ,text = 'Get Recommendations',relief = RAISED,font = ('Arial Italic', 18),bg='red4',fg='white',command=movie)
button.place(x = 150, y = 150)
L=tk.Label(label1,text='Movie Recommendation System',font=("Arial Italic",18),bg='red4',fg='white')
L.pack()
L1=tk.Label(label1,text='Make some popcorns,and enjoy your movie time!!',font=("Arial Italic",14),bg='red4',fg='white')
L1.place(x=100,y=100)
L1.pack()

root.mainloop()
 


# In[90]:


from tkinter import *
import tkinter as tk
from PIL import Image,ImageTk
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

root=tk.Tk()
root.geometry("600x400")
root.title("Recommendations")
root.configure(background="gray25")
movie=StringVar() 
s=StringVar()
canvas1 = tk.Canvas(root, width = 400, height = 400,bg='red4')
canvas1.pack(side="top")

def recommend():

    #cimporting csv file and extracting particular columns
    df = pd.read_csv("movies.csv")
    features = ['keywords','cast','genres','director']

    #combining features function
    def combine_features(row):
        return row['keywords']+" "+row['cast']+" "+row['genres']+" "+row['director']

    for feature in features:
        df[feature] = df[feature].fillna('') #filling all NaNs with blank string

    df["combined_features"] = df.apply(combine_features,axis=1)
    df.iloc[0].combined_features

    cv = CountVectorizer() #creating new CountVectorizer() object
    count_matrix = cv.fit_transform(df["combined_features"]) #feeding combined strings(movie contents) to CountVectorizer() object
    cosine_sim = cosine_similarity(count_matrix)

    def get_title_from_index(index):
        return df[df.index == index]["title"].values[0]
    def get_index_from_title(title):
        return df[df.title == title]["index"].values[0]

    print("Ënter movie")
    movie_user_likes=entry1.get()
    movie_index = get_index_from_title(movie_user_likes)
    similar_movies = list(enumerate(cosine_sim[movie_index]))     
    sorted_similar_movies = sorted(similar_movies,key=lambda x:x[1],reverse=True)[1:]
    i=0
   
    
   
    print("Top 10 similar movies to "+movie_user_likes+ " are:\n")
    for element in sorted_similar_movies:
        print(get_title_from_index(element[0]))
        i=i+1
        label = tk.Label(root, text= (get_title_from_index(element[0])),bg="red4",fg='white')
        canvas1.create_window(200,210, window=label)
        label.pack()
        if i>10:
            break 
        label.pack()
        l=tk.Label(root, text="Enjoy show time!!!",font=("Arial Italic",14),bg='red4',fg='white')
        canvas1.create_window(200, 220, window=l)
        
        
canvas1.place(x=100,y=50)
entry1 = tk.Entry (root)
canvas1.create_window(200, 270, window=entry1)

label1 = tk.Label(root, text="Enter your favourite movie here ;)",font=("Arial Italic",14),bg='red4',fg='white')
canvas1.create_window(200, 250, window=label1)
button = Button(root ,text = "Recommend!!!",relief = RAISED,font = ('Arial Italic', 18),bg='gray25',fg='white',command=recommend)
button.place(x = 210, y =350)
root.mainloop()
